# %%
import numpy as np
import pandas as pd

df = pd.read_excel("Task_Data.xlsx")
df
# Out:
#     ID   Team Country     NameF      NameL  Weight Height        DOB  \
# 0   15  Women  Canada  Jocelyne   Larocque   139.0    5'6 1988-05-19
# 1   16  Women  Canada  Brigette  Lacquette   180.0    5'6 1992-10-11
# 2   17  Women  Canada  Lauriane    Rougeau   167.0    5'8 1990-04-12
# 3   18  Women  Canada     Laura    Fortino   137.0    5'4 1991-01-30
# 4   19  Women  Canada   Meaghan  Mikkelson   139.0    5'9 1985-01-04
# ..  ..    ...     ...       ...        ...     ...    ...        ...
# 91  68  Women     USA      Alex     Rigsby   150.0    5'7 1992-01-03
# 92  69  Women     USA    Maddie     Rooney     NaN    5'5 1997-07-07
# 93  84    Men     USA     David     Leggio   185.0    6'0 1984-07-31
# 94  86    Men     USA   Brandon    Maxwell   196.0    6'1 1991-03-22
# 95  96    Men     USA      Ryan   Zapolski   203.0    6'0 1986-11-11
#
#         Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# 0      Ste. Anne   Man.  Defence   34  5.500000    66   22
# ...

# %%
df.fillna({ 
    'DOB':np.nan
})
df.dropna(subset=['Weight'])
# Out:
#     ID   Team Country     NameF      NameL  Weight Height        DOB  \
# 0   15  Women  Canada  Jocelyne   Larocque   139.0    5'6 1988-05-19
# 1   16  Women  Canada  Brigette  Lacquette   180.0    5'6 1992-10-11
# 2   17  Women  Canada  Lauriane    Rougeau   167.0    5'8 1990-04-12
# 3   18  Women  Canada     Laura    Fortino   137.0    5'4 1991-01-30
# 4   19  Women  Canada   Meaghan  Mikkelson   139.0    5'9 1985-01-04
# ..  ..    ...     ...       ...        ...     ...    ...        ...
# 90  57  Women     USA    Nicole    Hensley   155.0    5'7 1994-06-23
# 91  68  Women     USA      Alex     Rigsby   150.0    5'7 1992-01-03
# 93  84    Men     USA     David     Leggio   185.0    6'0 1984-07-31
# 94  86    Men     USA   Brandon    Maxwell   196.0    6'1 1991-03-22
# 95  96    Men     USA      Ryan   Zapolski   203.0    6'0 1986-11-11
#
#         Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# 0      Ste. Anne   Man.  Defence   34  5.500000    66   22
# ...

# %%
group=df.groupby('Pos')
group.head()
# Out:
#     ID   Team Country      NameF      NameL  Weight Height        DOB  \
# 0   15  Women  Canada   Jocelyne   Larocque   139.0    5'6 1988-05-19
# 1   16  Women  Canada   Brigette  Lacquette   180.0    5'6 1992-10-11
# 2   17  Women  Canada   Lauriane    Rougeau   167.0    5'8 1990-04-12
# 3   18  Women  Canada      Laura    Fortino   137.0    5'4 1991-01-30
# 4   19  Women  Canada    Meaghan  Mikkelson   139.0    5'9 1985-01-04
# 29   1  Women  Canada     Meghan     Agosta   148.0    5'7 1987-02-12
# 30   2  Women  Canada    Rebecca   Johnston   148.0    5'9 1989-09-24
# 31   3  Women  Canada      Laura     Stacey   156.0   5'10 1994-05-05
# 32   4  Women  Canada   Jennifer  Wakefield   172.0   5'10 1989-06-15
# 33   5  Women  Canada    Jillian   Saulnier   144.0    5'5 1992-03-07
# 84  21  Women  Canada    Shannon   Szabados   146.0    5'8 1986-08-06
# 85  22  Women  Canada  Geneviève    Lacasse   136.0    5'8 1989-05-05
# ...

# %%
df['HtIn'].loc[df['Team']=='Men'].median()
# Out:
# 72.0

# %%
df['Weight'].loc[df['Team']=='Women'].mean()
# Out:
# 151.38095238095238

# %%
pd.pivot_table(df,index=["Team","Age"],aggfunc=[np.mean,len])
# Out:
#                 mean                                             len          \
#                  BMI  HeightFt       HtIn         ID      Weight BMI Country
# Team  Age
# Men   24   24.000000  6.000000  72.000000  93.000000  179.000000   1       1
#       25   26.500000  6.291667  75.500000  78.000000  215.000000   2       2
#       26   26.000000  6.083333  73.000000  78.000000  196.000000   1       1
#       30   25.000000  5.958333  71.500000  33.500000  182.000000   2       2
#       31   25.666667  6.055556  72.666667  54.666667  192.000000   3       3
#       32   26.250000  6.000000  72.000000  38.250000  194.000000   4       4
#       33   17.333333  5.861111  70.333333  73.000000  182.500000   3       3
#       34   25.200000  5.866667  70.400000  78.000000  178.600000   5       5
#       35   26.000000  6.066667  72.800000  57.600000  195.500000  10      10
#       36   26.000000  5.916667  71.000000  57.166667  186.500000   6       6
# ...

# %%
df1=df.loc[(df["Team"]=='Men') & (df["Country"]=='Canada')]
df2=df.loc[(df["Team"]=='Women') & (df["Country"]=='USA')]
df1.join(df2,lsuffix='m',rsuffix='w')
# Out:
#     IDm Teamm Countrym      NameFm       NameLm  Weightm Heightm       DOBm  \
# 6    38   Men   Canada        Karl     Stollery    181.0    5'11 1987-11-21
# 7    39   Men   Canada       Chris          Lee    187.0     6'0 1980-10-03
# 8    40   Men   Canada        Chay      Genoway    170.0     5'9 1986-12-20
# 9    41   Men   Canada  Marc-Andre     Gragnani    205.0     6'3 1987-03-11
# 10   42   Men   Canada      Stefan      Elliott    190.0     6'1 1991-01-30
# 11   43   Men   Canada        Cody     Goloubef    200.0     6'1 1989-11-30
# 12   44   Men   Canada         Mat     Robinson    185.0    5'10 1986-06-20
# 13   45   Men   Canada       Maxim       Noreau    198.0     6'0 1987-05-24
# 43   24   Men   Canada     Gilbert        Brulé    190.0    5'11 1987-01-01
# 44   25   Men   Canada      Wojtek       Wolski    220.0     6'3 1986-02-24
# 45   26   Men   Canada       Derek          Roy    187.0     5'9 1983-05-04
# ...

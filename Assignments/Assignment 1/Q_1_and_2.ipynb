# %%
print("hello iitk")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
arr = np.random.rand(5)
print(arr,"\n")
arr2 = range(2,7)
print(arr2,"\n")
arr = np.random.randn(4,4)
print(arr.reshape(2,8),"\n")
plt.plot([1,2,3,4])
plt.show()
x = range(5)
plt.plot(x,[x1**3 for x1 in x])
plt.show()
x = range(3)
plt.plot(x,[((4-x1**2)**1/2) for x1 in x])
plt.show()
# Out:
# hello iitk
# [0.30607009 0.97516313 0.07807087 0.553864   0.62324738]
#
# range(2, 7)
#
# [[-0.22013278  1.17265282 -0.11755938  1.56233059 -0.3550637  -0.25357277
#   -1.0539564  -1.0280478 ]
#  [-0.04667562 -1.67612086 -0.1801162   0.21318456 -0.28649295  0.85368348
#    1.94210081 -0.34780877]]
